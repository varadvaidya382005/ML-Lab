# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('admission.csv')

# %%
x = df['GRE Score']
y = df['TOEFL Score']

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
plt.boxplot(df['GRE Score'])
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.plot(x,y)
plt.show()
